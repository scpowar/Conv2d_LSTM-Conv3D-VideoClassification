# %%
# !pip install opencv-python

# %%
import pandas as pd
import cv2
import numpy as np
from sklearn.utils import shuffle
import datetime
import os
from collections import deque
import copy
import matplotlib
import matplotlib.pyplot as plt
from keras.utils import np_utils

# %%
np.random.seed(30)
import random as rn
rn.seed(30)
import tensorflow as tf
from tensorflow import keras 
from keras import backend as K
tf.random.set_seed(30)

# %%
proj_data_dir = "C:/Users/scpow/Documents/LEARNING/IITB - MSC in ML & AI/05 - Deep Learning/06-Case Study - Gesture Recognition/Project_data/"
img = cv2.imread(proj_data_dir+'train/WIN_20180907_15_38_17_Pro_Left Swipe_new_Left Swipe_new/WIN_20180907_15_38_17_Pro_00029.png')
img.shape
# Out:
# (360, 360, 3)

# %%
plt.imshow(img/255)

# %%
# Initializing files

proj_data_dir = "C:/Users/scpow/Documents/LEARNING/IITB - MSC in ML & AI/05 - Deep Learning/06-Case Study - Gesture Recognition/Project_data/"

train_doc = np.random.permutation(open(proj_data_dir+'train.csv').readlines())
val_doc = np.random.permutation(open(proj_data_dir+'val.csv').readlines())

train_path = os.path.join(proj_data_dir,'train')
val_path = os.path.join(proj_data_dir,'val')

seq = 15
class_label = 5

# %%
train_path
# Out:
# 'C:/Users/scpow/Documents/LEARNING/IITB - MSC in ML & AI/05 - Deep Learning/06-Case Study - Gesture Recognition/Project_data/train'

# %%
# Custom Generator function

def generator(source_path, folder_list, batch_size):
    print( '\nSource path = ', source_path, '; batch size =', batch_size)
    img_idx = [i for i in range(10,25)] #create a list of image numbers you want to use for a particular video
    while True:
        
        t = np.random.permutation(folder_list)
        num_batches =  int(len(folder_list)/batch_size) # calculate the number of batches
        
        for batch in range(num_batches): # we iterate over the number of batches
            
            x = len(img_idx)
            y = 100
            z = 100
            
            batch_data = np.zeros((batch_size,x,y,z,3)) # x is the number of images you use for each video, (y,z) is the final size of the input images and 3 is the number of channels RGB
            batch_labels = np.zeros((batch_size,5)) # batch_labels is the one hot representation of the output
            
            for folder in range(batch_size): # iterate over the batch_size
                imgs = os.listdir(source_path+'/'+ t[folder + (batch*batch_size)].split(';')[0]) # read all the images in the folder
                
                for idx,item in enumerate(img_idx): #  Iterate iver the frames/images of a folder to read them in
                    image = cv2.imread(source_path+'/'+ t[folder + (batch*batch_size)].strip().split(';')[0]+'/'+imgs[item]).astype(np.float32)
                    
                    #crop the images and resize them. Note that the images are of 2 different shape 
                    image = cv2.resize(image, (100, 100))
                    #and the conv3D will throw error if the inputs in a batch have different shapes
                    
                    b=image[:,:,0]
                    g=image[:,:,1]
                    r=image[:,:,2]
                    
                    batch_data[folder,idx,:,:,0] = b/ 255.0  #normalise and feed in the image
                    batch_data[folder,idx,:,:,1] = g/ 255.0  #normalise and feed in the image
                    batch_data[folder,idx,:,:,2] = r/ 255.0  #normalise and feed in the image
                    
                batch_labels[folder, int(t[folder + (batch*batch_size)].strip().split(';')[2])] = 1
            yield batch_data, batch_labels #you yield the batch_data and the batch_labels, remember what does yield do

        
        # write the code for the remaining data points which are left after full batches
        
        if len(t)%batch_size != 0:
            
            x = len(img_idx)
            y = 100
            z = 100
            
            #batch_size = len(t)%batch_size
            
            batch_data = np.zeros((len(t)%batch_size,x,y,z,3)) # x is the number of images you use for each video, (y,z) is the final size of the input images and 3 is the number of channels RGB
            batch_labels = np.zeros((len(t)%batch_size,5)) # batch_labels is the one hot representation of the output
            
            for folder in range(len(t)%batch_size): # iterate over the batch_size
                imgs = os.listdir(source_path+'/'+ t[folder + (num_batches*batch_size)].split(';')[0]) # read all the images in the folder
                
                for idx,item in enumerate(img_idx): #  Iterate iver the frames/images of a folder to read them in
                    image = cv2.imread(source_path+'/'+ t[folder + (num_batches*batch_size)].strip().split(';')[0]+'/'+imgs[item]).astype(np.float32)
                    
                    #crop the images and resize them. Note that the images are of 2 different shape 
                    image = cv2.resize(image, (100, 100))
                    #and the conv3D will throw error if the inputs in a batch have different shapes
                    
                    b=image[:,:,0]
                    g=image[:,:,1]
                    r=image[:,:,2]
                    
                    batch_data[folder,idx,:,:,0] = b/ 255.0  #normalise and feed in the image
                    batch_data[folder,idx,:,:,1] = g/ 255.0  #normalise and feed in the image
                    batch_data[folder,idx,:,:,2] = r/ 255.0  #normalise and feed in the image
                    
                batch_labels[folder, int(t[folder + (num_batches*batch_size)].strip().split(';')[2])] = 1
            yield batch_data, batch_labels

# %%
'''
gen1 = generator(train_path, train_doc, batch_size)
x,y = next(gen1)

#folders, images, 100, 100, rgb_channel
print(x.shape)
plt.imshow(x[0][0])
print(y[0])
'''
# Out:
# '\ngen1 = generator(train_path, train_doc, batch_size)\nx,y = next(gen1)\n\n#folders, images, 100, 100, rgb_channel\nprint(x.shape)\nplt.imshow(x[0][0])\nprint(y[0])\n'

# %%
#Initializing parameters

curr_dt_time = datetime.datetime.now()
print('# curr_dt_time = ', curr_dt_time)
#train_path = '/notebooks/storage/Final_data/Collated_training/train'
#val_path = '/notebooks/storage/Final_data/Collated_training/val'
num_train_sequences = len(train_doc)
print('# training sequences =', num_train_sequences)
num_val_sequences = len(val_doc)
print('# validation sequences =', num_val_sequences)
num_epochs = 100 # choose the number of epochs
print ('# epochs =', num_epochs)
# Out:
# # curr_dt_time =  2022-07-13 00:40:53.609902
# # training sequences = 663
# # validation sequences = 100
# # epochs = 100

# %%
#train-val generator

train_generator = generator(train_path, train_doc, batch_size)
val_generator = generator(val_path, val_doc, batch_size)

# %%
#code to create Folder to save model at every epoch

model_name = 'model_init' + '_' + str(curr_dt_time).split('.')[0].replace(' ','_').replace(':','') + '/'
    
if not os.path.exists(model_name):
    os.mkdir(model_name)
        
filepath = model_name + 'model-{epoch:05d}-{loss:.5f}-{categorical_accuracy:.5f}-{val_loss:.5f}-{val_categorical_accuracy:.5f}.h5'

checkpoint = tf.keras.callbacks.ModelCheckpoint(filepath, monitor='val_loss', verbose=1, save_best_only=False, save_weights_only=False, mode='auto', period=1)

LR = tf.keras.callbacks.ReduceLROnPlateau(monitor='val_loss', factor=0.2,patience=5, min_lr=0.001)
callbacks_list = [checkpoint, LR]
# Out:
# WARNING:tensorflow:`period` argument is deprecated. Please use `save_freq` to specify the frequency in number of batches seen.
# WARNING:tensorflow:`period` argument is deprecated. Please use `save_freq` to specify the frequency in number of batches seen.

# %%
#Some more parameters

batch_size = 150 
#experiment with the batch size
#300 is too high; kernel reset
#150 working well for Conv2d+LSTM model

steps_per_epoch = 0

validation_steps = 0

num_train_sequences = len(train_doc)
num_val_sequences = len(val_doc)

if (num_train_sequences%batch_size) == 0:
    steps_per_epoch = int(num_train_sequences/batch_size)
else:
    steps_per_epoch = (num_train_sequences//batch_size) + 1

if (num_val_sequences%batch_size) == 0:
    validation_steps = int(num_val_sequences/batch_size)
else:
    validation_steps = (num_val_sequences//batch_size) + 1
    
print(f'steps_per_epoch: {steps_per_epoch}')
print(f'validation_steps: {validation_steps}')
# Out:
# steps_per_epoch: 23
# validation_steps: 4

# %% [markdown]
# # Model

# %%
from keras.models import Sequential, Model
from keras.layers import Dense, GRU, Flatten, TimeDistributed, BatchNormalization, Activation, Dropout
from keras.layers.convolutional import Conv3D, MaxPooling3D, Conv2D, MaxPooling2D
from keras.layers.recurrent import LSTM
from keras.callbacks import ModelCheckpoint, ReduceLROnPlateau
from tensorflow.python.keras import regularizers
from keras import optimizers

# %%
#custom function to plot accuracy and loss of train and validation data set

def accuracy_loss_plt(model_history):
    acc = model_history.history['categorical_accuracy']
    val_acc = model_history.history['val_categorical_accuracy']

    loss = model_history.history['loss']
    val_loss = model_history.history['val_loss']
    
    best_val_accuracy=  max(model_history.history['val_categorical_accuracy'])
    best_val_loss = min(model_history.history['val_loss'])
    
    #epochs_range = range(epochs)

    plt.figure(figsize=(16, 5))
    plt.subplot(1, 2, 1)
    plt.plot( acc, label='Training Accuracy')
    plt.plot( val_acc, label='Validation Accuracy')
    plt.legend(loc='lower right')
    plt.title('Training and Validation Accuracy')
    plt.xlabel('epoch')
    plt.ylabel('accuracy')

    plt.subplot(1, 2, 2)
    plt.plot( loss, label='Training Loss')
    plt.plot( val_loss, label='Validation Loss')
    plt.legend(loc='upper right')
    plt.title('Training and Validation Loss')
    plt.xlabel('epoch')
    plt.ylabel('loss')
    plt.show()   
    
    print(f'best_val_accuracy: {best_val_accuracy}')
    print(f'best_val_loss: {best_val_loss}')

# %% [markdown]
# ## Conv2D + LSTM Model

# %%
#write your model here

model = Sequential()

model.add(TimeDistributed(Conv2D(16, (3, 3), padding='same',activation = 'relu'),input_shape = (15, 100, 100, 3)))
model.add(TimeDistributed(MaxPooling2D((4, 4)))) 

model.add(TimeDistributed(Conv2D(32, (3, 3), padding='same',activation = 'relu')))
model.add(TimeDistributed(MaxPooling2D((4, 4))))
    
model.add(TimeDistributed(Conv2D(64, (3, 3), padding='same',activation = 'relu')))
model.add(TimeDistributed(MaxPooling2D((2, 2))))
    
model.add(TimeDistributed(Conv2D(64, (3, 3), padding='same',activation = 'relu')))
model.add(TimeDistributed(MaxPooling2D((2, 2))))
                                      
model.add(TimeDistributed(Flatten()))
                                     
model.add(LSTM(32))
                                      
model.add(Dense(class_label, activation = 'softmax'))

# %%
optimiser = 'adam' #write your optimizer
model.compile(optimizer=optimiser, loss='categorical_crossentropy', metrics=['categorical_accuracy'])
print (model.summary())
# Out:
# Model: "sequential"
# _________________________________________________________________
# Layer (type)                 Output Shape              Param #
# =================================================================
# time_distributed (TimeDistri (None, 15, 100, 100, 16)  448
# _________________________________________________________________
# time_distributed_1 (TimeDist (None, 15, 25, 25, 16)    0
# _________________________________________________________________
# time_distributed_2 (TimeDist (None, 15, 25, 25, 32)    4640
# _________________________________________________________________
# time_distributed_3 (TimeDist (None, 15, 6, 6, 32)      0
# _________________________________________________________________
# time_distributed_4 (TimeDist (None, 15, 6, 6, 64)      18496
# _________________________________________________________________
# time_distributed_5 (TimeDist (None, 15, 3, 3, 64)      0
# _________________________________________________________________
# time_distributed_6 (TimeDist (None, 15, 3, 3, 64)      36928
# _________________________________________________________________
# time_distributed_7 (TimeDist (None, 15, 1, 1, 64)      0
# _________________________________________________________________
# time_distributed_8 (TimeDist (None, 15, 64)            0
# _________________________________________________________________
# lstm (LSTM)                  (None, 32)                12416
# _________________________________________________________________
# dense (Dense)                (None, 5)                 165
# =================================================================
# Total params: 73,093
# Trainable params: 73,093
# Non-trainable params: 0
# _________________________________________________________________
# None

# %%
model_history = model.fit_generator(train_generator, steps_per_epoch=steps_per_epoch, epochs=num_epochs, verbose=1, 
                    callbacks=callbacks_list, validation_data=val_generator, 
                    validation_steps=validation_steps, class_weight=None, workers=1, initial_epoch=0)
# Out:
# Epoch 1/100
# 5/5 [==============================] - ETA: 0s - loss: 1.6037 - categorical_accuracy: 0.1885 Source path =  C:/Users/scpow/Documents/LEARNING/IITB - MSC in ML & AI/05 - Deep Learning/06-Case Study - Gesture Recognition/Project_data/val ; batch size = 150
# 5/5 [==============================] - 116s 26s/step - loss: 1.6037 - categorical_accuracy: 0.1885 - val_loss: 1.5911 - val_categorical_accuracy: 0.2300
#
# Epoch 00001: saving model to model_init_2022-07-11_234103\model-00001-1.60372-0.18854-1.59110-0.23000.h5
# Epoch 2/100
# 5/5 [==============================] - 100s 23s/step - loss: 1.6004 - categorical_accuracy: 0.1916 - val_loss: 1.5860 - val_categorical_accuracy: 0.2300
#
# Epoch 00002: saving model to model_init_2022-07-11_234103\model-00002-1.60039-0.19155-1.58597-0.23000.h5
# Epoch 3/100
# 5/5 [==============================] - 100s 22s/step - loss: 1.5832 - categorical_accuracy: 0.2142 - val_loss: 1.5713 - val_categorical_accuracy: 0.2300
#
# Epoch 00003: saving model to model_init_2022-07-11_234103\model-00003-1.58316-0.21418-1.57126-0.23000.h5
# Epoch 4/100
# 5/5 [==============================] - 85s 19s/step - loss: 1.5704 - categorical_accuracy: 0.2323 - val_loss: 1.5480 - val_categorical_accuracy: 0.4200
#
# Epoch 00004: saving model to model_init_2022-07-11_234103\model-00004-1.57043-0.23228-1.54797-0.42000.h5
# Epoch 5/100
# 5/5 [==============================] - 90s 20s/step - loss: 1.5141 - categorical_accuracy: 0.3152 - val_loss: 1.4631 - val_categorical_accuracy: 0.4400
#
# Epoch 00005: saving model to model_init_2022-07-11_234103\model-00005-1.51406-0.31523-1.46309-0.44000.h5
# Epoch 6/100
# 5/5 [==============================] - 92s 21s/step - loss: 1.4181 - categorical_accuracy: 0.4238 - val_loss: 1.3980 - val_categorical_accuracy: 0.4300
#
# Epoch 00006: saving model to model_init_2022-07-11_234103\model-00006-1.41814-0.42383-1.39796-0.43000.h5
# Epoch 7/100
# 5/5 [==============================] - 73s 16s/step - loss: 1.4041 - categorical_accuracy: 0.3952 - val_loss: 1.4100 - val_categorical_accuracy: 0.4200
#
# Epoch 00007: saving model to model_init_2022-07-11_234103\model-00007-1.40407-0.39517-1.41001-0.42000.h5
# Epoch 8/100
# 5/5 [==============================] - 72s 16s/step - loss: 1.2954 - categorical_accuracy: 0.4962 - val_loss: 1.2621 - val_categorical_accuracy: 0.4900
#
# Epoch 00008: saving model to model_init_2022-07-11_234103\model-00008-1.29540-0.49623-1.26210-0.49000.h5
# Epoch 9/100
# 5/5 [==============================] - 58s 13s/step - loss: 1.2634 - categorical_accuracy: 0.4811 - val_loss: 1.3081 - val_categorical_accuracy: 0.4500
#
# Epoch 00009: saving model to model_init_2022-07-11_234103\model-00009-1.26338-0.48115-1.30812-0.45000.h5
# Epoch 10/100
# 5/5 [==============================] - 57s 12s/step - loss: 1.1944 - categorical_accuracy: 0.5098 - val_loss: 1.2535 - val_categorical_accuracy: 0.4400
#
# Epoch 00010: saving model to model_init_2022-07-11_234103\model-00010-1.19441-0.50980-1.25345-0.44000.h5
# Epoch 11/100
# 5/5 [==============================] - 55s 12s/step - loss: 1.1477 - categorical_accuracy: 0.5430 - val_loss: 1.2528 - val_categorical_accuracy: 0.5400
#
# Epoch 00011: saving model to model_init_2022-07-11_234103\model-00011-1.14767-0.54299-1.25278-0.54000.h5
# Epoch 12/100
# 5/5 [==============================] - 48s 11s/step - loss: 1.2178 - categorical_accuracy: 0.5143 - val_loss: 1.1909 - val_categorical_accuracy: 0.5200
#
# Epoch 00012: saving model to model_init_2022-07-11_234103\model-00012-1.21778-0.51433-1.19093-0.52000.h5
# Epoch 13/100
# 5/5 [==============================] - 57s 13s/step - loss: 1.1802 - categorical_accuracy: 0.5324 - val_loss: 1.1582 - val_categorical_accuracy: 0.5300
#
# Epoch 00013: saving model to model_init_2022-07-11_234103\model-00013-1.18021-0.53243-1.15818-0.53000.h5
# Epoch 14/100
# 5/5 [==============================] - 50s 11s/step - loss: 1.0865 - categorical_accuracy: 0.5807 - val_loss: 1.1473 - val_categorical_accuracy: 0.5700
#
# Epoch 00014: saving model to model_init_2022-07-11_234103\model-00014-1.08655-0.58069-1.14735-0.57000.h5
# Epoch 15/100
# 5/5 [==============================] - 51s 11s/step - loss: 1.0280 - categorical_accuracy: 0.6094 - val_loss: 1.0901 - val_categorical_accuracy: 0.5700
#
# Epoch 00015: saving model to model_init_2022-07-11_234103\model-00015-1.02796-0.60935-1.09010-0.57000.h5
# Epoch 16/100
# 5/5 [==============================] - 50s 11s/step - loss: 0.9239 - categorical_accuracy: 0.6667 - val_loss: 1.0824 - val_categorical_accuracy: 0.5600
#
# Epoch 00016: saving model to model_init_2022-07-11_234103\model-00016-0.92389-0.66667-1.08235-0.56000.h5
# Epoch 17/100
# 5/5 [==============================] - 49s 11s/step - loss: 0.9673 - categorical_accuracy: 0.6199 - val_loss: 0.9963 - val_categorical_accuracy: 0.6400
#
# Epoch 00017: saving model to model_init_2022-07-11_234103\model-00017-0.96725-0.61991-0.99627-0.64000.h5
# Epoch 18/100
# 5/5 [==============================] - 50s 11s/step - loss: 0.8997 - categorical_accuracy: 0.6802 - val_loss: 0.9948 - val_categorical_accuracy: 0.5600
#
# Epoch 00018: saving model to model_init_2022-07-11_234103\model-00018-0.89967-0.68024-0.99485-0.56000.h5
# Epoch 19/100
# 5/5 [==============================] - 52s 12s/step - loss: 0.9131 - categorical_accuracy: 0.6667 - val_loss: 1.0115 - val_categorical_accuracy: 0.6100
#
# Epoch 00019: saving model to model_init_2022-07-11_234103\model-00019-0.91315-0.66667-1.01148-0.61000.h5
# Epoch 20/100
# 5/5 [==============================] - 51s 11s/step - loss: 0.7988 - categorical_accuracy: 0.7225 - val_loss: 0.8977 - val_categorical_accuracy: 0.6300
#
# Epoch 00020: saving model to model_init_2022-07-11_234103\model-00020-0.79875-0.72247-0.89766-0.63000.h5
# Epoch 21/100
# 5/5 [==============================] - 48s 11s/step - loss: 0.7582 - categorical_accuracy: 0.7225 - val_loss: 0.8916 - val_categorical_accuracy: 0.6400
#
# Epoch 00021: saving model to model_init_2022-07-11_234103\model-00021-0.75824-0.72247-0.89156-0.64000.h5
# Epoch 22/100
# 5/5 [==============================] - 49s 11s/step - loss: 0.6733 - categorical_accuracy: 0.7617 - val_loss: 0.8789 - val_categorical_accuracy: 0.6200
#
# Epoch 00022: saving model to model_init_2022-07-11_234103\model-00022-0.67331-0.76169-0.87894-0.62000.h5
# Epoch 23/100
# 5/5 [==============================] - 47s 10s/step - loss: 0.6461 - categorical_accuracy: 0.7662 - val_loss: 1.0525 - val_categorical_accuracy: 0.5900
#
# Epoch 00023: saving model to model_init_2022-07-11_234103\model-00023-0.64614-0.76621-1.05254-0.59000.h5
# Epoch 24/100
# 5/5 [==============================] - 49s 11s/step - loss: 0.7779 - categorical_accuracy: 0.7104 - val_loss: 1.2038 - val_categorical_accuracy: 0.5100
#
# Epoch 00024: saving model to model_init_2022-07-11_234103\model-00024-0.77790-0.71041-1.20375-0.51000.h5
# Epoch 25/100
# 5/5 [==============================] - 48s 11s/step - loss: 0.7255 - categorical_accuracy: 0.7285 - val_loss: 1.0407 - val_categorical_accuracy: 0.5500
#
# Epoch 00025: saving model to model_init_2022-07-11_234103\model-00025-0.72553-0.72851-1.04066-0.55000.h5
# Epoch 26/100
# 5/5 [==============================] - 47s 11s/step - loss: 0.6481 - categorical_accuracy: 0.7647 - val_loss: 0.8941 - val_categorical_accuracy: 0.6400
#
# Epoch 00026: saving model to model_init_2022-07-11_234103\model-00026-0.64806-0.76471-0.89413-0.64000.h5
# Epoch 27/100
# 5/5 [==============================] - 49s 11s/step - loss: 0.5723 - categorical_accuracy: 0.7919 - val_loss: 0.8474 - val_categorical_accuracy: 0.6700
#
# Epoch 00027: saving model to model_init_2022-07-11_234103\model-00027-0.57225-0.79186-0.84744-0.67000.h5
# Epoch 28/100
# 5/5 [==============================] - 49s 11s/step - loss: 0.5090 - categorical_accuracy: 0.8205 - val_loss: 0.8668 - val_categorical_accuracy: 0.6500
#
# Epoch 00028: saving model to model_init_2022-07-11_234103\model-00028-0.50904-0.82051-0.86679-0.65000.h5
# Epoch 29/100
# 5/5 [==============================] - 48s 11s/step - loss: 0.5303 - categorical_accuracy: 0.8054 - val_loss: 0.9020 - val_categorical_accuracy: 0.6600
#
# Epoch 00029: saving model to model_init_2022-07-11_234103\model-00029-0.53027-0.80543-0.90196-0.66000.h5
# Epoch 30/100
# 5/5 [==============================] - 49s 11s/step - loss: 0.4993 - categorical_accuracy: 0.8235 - val_loss: 1.0691 - val_categorical_accuracy: 0.6000
#
# Epoch 00030: saving model to model_init_2022-07-11_234103\model-00030-0.49926-0.82353-1.06914-0.60000.h5
# Epoch 31/100
# 5/5 [==============================] - 49s 11s/step - loss: 0.5620 - categorical_accuracy: 0.7828 - val_loss: 0.8996 - val_categorical_accuracy: 0.6200
#
# Epoch 00031: saving model to model_init_2022-07-11_234103\model-00031-0.56198-0.78281-0.89963-0.62000.h5
# Epoch 32/100
# 5/5 [==============================] - 49s 11s/step - loss: 0.4823 - categorical_accuracy: 0.8281 - val_loss: 0.8338 - val_categorical_accuracy: 0.7000
#
# Epoch 00032: saving model to model_init_2022-07-11_234103\model-00032-0.48227-0.82805-0.83377-0.70000.h5
# Epoch 33/100
# 5/5 [==============================] - 50s 11s/step - loss: 0.4210 - categorical_accuracy: 0.8567 - val_loss: 0.8769 - val_categorical_accuracy: 0.6000
#
# Epoch 00033: saving model to model_init_2022-07-11_234103\model-00033-0.42095-0.85671-0.87689-0.60000.h5
# Epoch 34/100
# 5/5 [==============================] - 50s 11s/step - loss: 0.4379 - categorical_accuracy: 0.8401 - val_loss: 0.8819 - val_categorical_accuracy: 0.6400
#
# Epoch 00034: saving model to model_init_2022-07-11_234103\model-00034-0.43786-0.84012-0.88188-0.64000.h5
# Epoch 35/100
# 5/5 [==============================] - 48s 11s/step - loss: 0.4019 - categorical_accuracy: 0.8552 - val_loss: 0.9425 - val_categorical_accuracy: 0.6200
#
# Epoch 00035: saving model to model_init_2022-07-11_234103\model-00035-0.40186-0.85520-0.94254-0.62000.h5
# Epoch 36/100
# 5/5 [==============================] - 49s 11s/step - loss: 0.3717 - categorical_accuracy: 0.8688 - val_loss: 1.0104 - val_categorical_accuracy: 0.6000
#
# Epoch 00036: saving model to model_init_2022-07-11_234103\model-00036-0.37173-0.86878-1.01040-0.60000.h5
# Epoch 37/100
# 5/5 [==============================] - 47s 10s/step - loss: 0.4103 - categorical_accuracy: 0.8522 - val_loss: 1.0236 - val_categorical_accuracy: 0.6200
#
# Epoch 00037: saving model to model_init_2022-07-11_234103\model-00037-0.41029-0.85219-1.02360-0.62000.h5
# Epoch 38/100
# 5/5 [==============================] - 47s 10s/step - loss: 0.3435 - categorical_accuracy: 0.8793 - val_loss: 0.9484 - val_categorical_accuracy: 0.6600
#
# Epoch 00038: saving model to model_init_2022-07-11_234103\model-00038-0.34348-0.87934-0.94843-0.66000.h5
# Epoch 39/100
# 5/5 [==============================] - 46s 10s/step - loss: 0.3013 - categorical_accuracy: 0.9080 - val_loss: 0.9460 - val_categorical_accuracy: 0.6600
#
# Epoch 00039: saving model to model_init_2022-07-11_234103\model-00039-0.30134-0.90799-0.94598-0.66000.h5
# Epoch 40/100
# 5/5 [==============================] - 67s 15s/step - loss: 0.2759 - categorical_accuracy: 0.9065 - val_loss: 1.0666 - val_categorical_accuracy: 0.6300
#
# Epoch 00040: saving model to model_init_2022-07-11_234103\model-00040-0.27592-0.90649-1.06662-0.63000.h5
# Epoch 41/100
# 5/5 [==============================] - 69s 16s/step - loss: 0.2647 - categorical_accuracy: 0.9201 - val_loss: 1.0421 - val_categorical_accuracy: 0.6200
#
# Epoch 00041: saving model to model_init_2022-07-11_234103\model-00041-0.26470-0.92006-1.04210-0.62000.h5
# Epoch 42/100
# 5/5 [==============================] - 69s 16s/step - loss: 0.2748 - categorical_accuracy: 0.9065 - val_loss: 0.9110 - val_categorical_accuracy: 0.7000
#
# Epoch 00042: saving model to model_init_2022-07-11_234103\model-00042-0.27476-0.90649-0.91105-0.70000.h5
# Epoch 43/100
# 5/5 [==============================] - 70s 16s/step - loss: 0.2729 - categorical_accuracy: 0.9005 - val_loss: 0.9991 - val_categorical_accuracy: 0.6700
#
# Epoch 00043: saving model to model_init_2022-07-11_234103\model-00043-0.27289-0.90045-0.99908-0.67000.h5
# Epoch 44/100
# 5/5 [==============================] - 68s 16s/step - loss: 0.2508 - categorical_accuracy: 0.9246 - val_loss: 1.1184 - val_categorical_accuracy: 0.6300
#
# Epoch 00044: saving model to model_init_2022-07-11_234103\model-00044-0.25084-0.92459-1.11839-0.63000.h5
# Epoch 45/100
# 5/5 [==============================] - 74s 17s/step - loss: 0.2703 - categorical_accuracy: 0.9050 - val_loss: 0.9525 - val_categorical_accuracy: 0.7300
#
# Epoch 00045: saving model to model_init_2022-07-11_234103\model-00045-0.27034-0.90498-0.95252-0.73000.h5
# Epoch 46/100
# 5/5 [==============================] - 72s 17s/step - loss: 0.1855 - categorical_accuracy: 0.9457 - val_loss: 1.1268 - val_categorical_accuracy: 0.6100
#
# Epoch 00046: saving model to model_init_2022-07-11_234103\model-00046-0.18555-0.94570-1.12682-0.61000.h5
# Epoch 47/100
# 5/5 [==============================] - 72s 17s/step - loss: 0.1986 - categorical_accuracy: 0.9412 - val_loss: 1.0491 - val_categorical_accuracy: 0.6900
#
# Epoch 00047: saving model to model_init_2022-07-11_234103\model-00047-0.19859-0.94118-1.04910-0.69000.h5
# Epoch 48/100
# 5/5 [==============================] - 71s 16s/step - loss: 0.1516 - categorical_accuracy: 0.9638 - val_loss: 1.1245 - val_categorical_accuracy: 0.6700
#
# Epoch 00048: saving model to model_init_2022-07-11_234103\model-00048-0.15156-0.96380-1.12445-0.67000.h5
# Epoch 49/100
# 5/5 [==============================] - 70s 16s/step - loss: 0.1371 - categorical_accuracy: 0.9668 - val_loss: 1.1239 - val_categorical_accuracy: 0.6500
#
# Epoch 00049: saving model to model_init_2022-07-11_234103\model-00049-0.13708-0.96682-1.12393-0.65000.h5
# Epoch 50/100
# 5/5 [==============================] - 69s 16s/step - loss: 0.1213 - categorical_accuracy: 0.9713 - val_loss: 1.0615 - val_categorical_accuracy: 0.6400
#
# Epoch 00050: saving model to model_init_2022-07-11_234103\model-00050-0.12133-0.97134-1.06147-0.64000.h5
# Epoch 51/100
# 5/5 [==============================] - 70s 16s/step - loss: 0.0873 - categorical_accuracy: 0.9894 - val_loss: 1.2557 - val_categorical_accuracy: 0.6100
#
# Epoch 00051: saving model to model_init_2022-07-11_234103\model-00051-0.08730-0.98944-1.25571-0.61000.h5
# Epoch 52/100
# 5/5 [==============================] - 72s 16s/step - loss: 0.0668 - categorical_accuracy: 0.9940 - val_loss: 1.1977 - val_categorical_accuracy: 0.6700
#
# Epoch 00052: saving model to model_init_2022-07-11_234103\model-00052-0.06683-0.99397-1.19775-0.67000.h5
# Epoch 53/100
# 5/5 [==============================] - 70s 16s/step - loss: 0.1680 - categorical_accuracy: 0.9502 - val_loss: 1.7577 - val_categorical_accuracy: 0.5100
#
# Epoch 00053: saving model to model_init_2022-07-11_234103\model-00053-0.16798-0.95023-1.75770-0.51000.h5
# Epoch 54/100
# 5/5 [==============================] - 70s 16s/step - loss: 0.2694 - categorical_accuracy: 0.9005 - val_loss: 1.2293 - val_categorical_accuracy: 0.6300
#
# Epoch 00054: saving model to model_init_2022-07-11_234103\model-00054-0.26936-0.90045-1.22930-0.63000.h5
# Epoch 55/100
# 5/5 [==============================] - 71s 16s/step - loss: 0.2195 - categorical_accuracy: 0.9246 - val_loss: 0.9249 - val_categorical_accuracy: 0.6700
#
# Epoch 00055: saving model to model_init_2022-07-11_234103\model-00055-0.21951-0.92459-0.92495-0.67000.h5
# Epoch 56/100
# 5/5 [==============================] - 70s 16s/step - loss: 0.1213 - categorical_accuracy: 0.9744 - val_loss: 1.0162 - val_categorical_accuracy: 0.6400
#
# Epoch 00056: saving model to model_init_2022-07-11_234103\model-00056-0.12129-0.97436-1.01616-0.64000.h5
# Epoch 57/100
# 5/5 [==============================] - 70s 16s/step - loss: 0.1633 - categorical_accuracy: 0.9502 - val_loss: 1.1662 - val_categorical_accuracy: 0.6500
#
# Epoch 00057: saving model to model_init_2022-07-11_234103\model-00057-0.16334-0.95023-1.16617-0.65000.h5
# Epoch 58/100
# 5/5 [==============================] - 70s 16s/step - loss: 0.1899 - categorical_accuracy: 0.9336 - val_loss: 1.0983 - val_categorical_accuracy: 0.6700
#
# Epoch 00058: saving model to model_init_2022-07-11_234103\model-00058-0.18988-0.93363-1.09827-0.67000.h5
# Epoch 59/100
# 5/5 [==============================] - 70s 16s/step - loss: 0.1917 - categorical_accuracy: 0.9351 - val_loss: 0.9560 - val_categorical_accuracy: 0.6900
#
# Epoch 00059: saving model to model_init_2022-07-11_234103\model-00059-0.19173-0.93514-0.95599-0.69000.h5
# Epoch 60/100
# 5/5 [==============================] - 71s 16s/step - loss: 0.1710 - categorical_accuracy: 0.9442 - val_loss: 1.0985 - val_categorical_accuracy: 0.6400
#
# Epoch 00060: saving model to model_init_2022-07-11_234103\model-00060-0.17101-0.94419-1.09854-0.64000.h5
# Epoch 61/100
# 5/5 [==============================] - 69s 16s/step - loss: 0.1453 - categorical_accuracy: 0.9532 - val_loss: 1.3321 - val_categorical_accuracy: 0.5600
#
# Epoch 00061: saving model to model_init_2022-07-11_234103\model-00061-0.14532-0.95324-1.33205-0.56000.h5
# Epoch 62/100
# 5/5 [==============================] - 70s 16s/step - loss: 0.1658 - categorical_accuracy: 0.9502 - val_loss: 0.9923 - val_categorical_accuracy: 0.7100
#
# Epoch 00062: saving model to model_init_2022-07-11_234103\model-00062-0.16579-0.95023-0.99230-0.71000.h5
# Epoch 63/100
# 5/5 [==============================] - 71s 16s/step - loss: 0.1266 - categorical_accuracy: 0.9668 - val_loss: 1.1376 - val_categorical_accuracy: 0.6300
#
# Epoch 00063: saving model to model_init_2022-07-11_234103\model-00063-0.12663-0.96682-1.13759-0.63000.h5
# Epoch 64/100
# 5/5 [==============================] - 71s 16s/step - loss: 0.0816 - categorical_accuracy: 0.9864 - val_loss: 1.0394 - val_categorical_accuracy: 0.7000
#
# Epoch 00064: saving model to model_init_2022-07-11_234103\model-00064-0.08156-0.98643-1.03945-0.70000.h5
# Epoch 65/100
# 5/5 [==============================] - 70s 16s/step - loss: 0.0474 - categorical_accuracy: 0.9940 - val_loss: 1.0824 - val_categorical_accuracy: 0.6800
#
# Epoch 00065: saving model to model_init_2022-07-11_234103\model-00065-0.04743-0.99397-1.08240-0.68000.h5
# Epoch 66/100
# 5/5 [==============================] - 70s 16s/step - loss: 0.0679 - categorical_accuracy: 0.9834 - val_loss: 1.1238 - val_categorical_accuracy: 0.7200
#
# Epoch 00066: saving model to model_init_2022-07-11_234103\model-00066-0.06785-0.98341-1.12382-0.72000.h5
# Epoch 67/100
# 5/5 [==============================] - 71s 16s/step - loss: 0.0695 - categorical_accuracy: 0.9804 - val_loss: 1.3809 - val_categorical_accuracy: 0.6500
#
# Epoch 00067: saving model to model_init_2022-07-11_234103\model-00067-0.06954-0.98039-1.38094-0.65000.h5
# Epoch 68/100
# 5/5 [==============================] - 72s 17s/step - loss: 0.0779 - categorical_accuracy: 0.9759 - val_loss: 1.1307 - val_categorical_accuracy: 0.6900
#
# Epoch 00068: saving model to model_init_2022-07-11_234103\model-00068-0.07788-0.97587-1.13075-0.69000.h5
# Epoch 69/100
# 5/5 [==============================] - 72s 16s/step - loss: 0.0464 - categorical_accuracy: 0.9925 - val_loss: 1.1209 - val_categorical_accuracy: 0.6900
#
# Epoch 00069: saving model to model_init_2022-07-11_234103\model-00069-0.04643-0.99246-1.12088-0.69000.h5
# Epoch 70/100
# 5/5 [==============================] - 76s 17s/step - loss: 0.0433 - categorical_accuracy: 0.9894 - val_loss: 1.0107 - val_categorical_accuracy: 0.7300
#
# Epoch 00070: saving model to model_init_2022-07-11_234103\model-00070-0.04332-0.98944-1.01074-0.73000.h5
# Epoch 71/100
# 5/5 [==============================] - 74s 17s/step - loss: 0.0440 - categorical_accuracy: 0.9925 - val_loss: 1.0482 - val_categorical_accuracy: 0.7000
#
# Epoch 00071: saving model to model_init_2022-07-11_234103\model-00071-0.04397-0.99246-1.04822-0.70000.h5
# Epoch 72/100
# 5/5 [==============================] - 77s 18s/step - loss: 0.0410 - categorical_accuracy: 0.9925 - val_loss: 1.2825 - val_categorical_accuracy: 0.6800
#
# Epoch 00072: saving model to model_init_2022-07-11_234103\model-00072-0.04101-0.99246-1.28247-0.68000.h5
# Epoch 73/100
# 5/5 [==============================] - 72s 16s/step - loss: 0.0390 - categorical_accuracy: 0.9940 - val_loss: 1.1296 - val_categorical_accuracy: 0.7100
#
# Epoch 00073: saving model to model_init_2022-07-11_234103\model-00073-0.03897-0.99397-1.12958-0.71000.h5
# Epoch 74/100
# 5/5 [==============================] - 74s 17s/step - loss: 0.0413 - categorical_accuracy: 0.9879 - val_loss: 1.4427 - val_categorical_accuracy: 0.6600
#
# Epoch 00074: saving model to model_init_2022-07-11_234103\model-00074-0.04135-0.98793-1.44267-0.66000.h5
# Epoch 75/100
# 5/5 [==============================] - 72s 16s/step - loss: 0.1188 - categorical_accuracy: 0.9638 - val_loss: 1.2092 - val_categorical_accuracy: 0.6900
#
# Epoch 00075: saving model to model_init_2022-07-11_234103\model-00075-0.11877-0.96380-1.20917-0.69000.h5
# Epoch 76/100
# 5/5 [==============================] - 73s 17s/step - loss: 0.2666 - categorical_accuracy: 0.9276 - val_loss: 1.1536 - val_categorical_accuracy: 0.6900
#
# Epoch 00076: saving model to model_init_2022-07-11_234103\model-00076-0.26665-0.92760-1.15359-0.69000.h5
# Epoch 77/100
# 5/5 [==============================] - 70s 16s/step - loss: 0.2902 - categorical_accuracy: 0.9246 - val_loss: 1.1387 - val_categorical_accuracy: 0.6200
#
# Epoch 00077: saving model to model_init_2022-07-11_234103\model-00077-0.29022-0.92459-1.13874-0.62000.h5
# Epoch 78/100
# 5/5 [==============================] - 72s 16s/step - loss: 0.2750 - categorical_accuracy: 0.9125 - val_loss: 0.8366 - val_categorical_accuracy: 0.6900
#
# Epoch 00078: saving model to model_init_2022-07-11_234103\model-00078-0.27503-0.91252-0.83660-0.69000.h5
# Epoch 79/100
# 5/5 [==============================] - 75s 17s/step - loss: 0.2339 - categorical_accuracy: 0.9140 - val_loss: 0.8462 - val_categorical_accuracy: 0.7400
#
# Epoch 00079: saving model to model_init_2022-07-11_234103\model-00079-0.23391-0.91403-0.84615-0.74000.h5
# Epoch 80/100
# 5/5 [==============================] - 78s 18s/step - loss: 0.1059 - categorical_accuracy: 0.9774 - val_loss: 0.9605 - val_categorical_accuracy: 0.7100
#
# Epoch 00080: saving model to model_init_2022-07-11_234103\model-00080-0.10588-0.97738-0.96047-0.71000.h5
# Epoch 81/100
# 5/5 [==============================] - 80s 18s/step - loss: 0.0793 - categorical_accuracy: 0.9774 - val_loss: 1.1045 - val_categorical_accuracy: 0.6700
#
# Epoch 00081: saving model to model_init_2022-07-11_234103\model-00081-0.07930-0.97738-1.10450-0.67000.h5
# Epoch 82/100
# 5/5 [==============================] - 80s 18s/step - loss: 0.0550 - categorical_accuracy: 0.9864 - val_loss: 1.1742 - val_categorical_accuracy: 0.6900
#
# Epoch 00082: saving model to model_init_2022-07-11_234103\model-00082-0.05497-0.98643-1.17422-0.69000.h5
# Epoch 83/100
# 5/5 [==============================] - 75s 17s/step - loss: 0.0328 - categorical_accuracy: 0.9955 - val_loss: 1.2496 - val_categorical_accuracy: 0.7000
#
# Epoch 00083: saving model to model_init_2022-07-11_234103\model-00083-0.03277-0.99548-1.24955-0.70000.h5
# Epoch 84/100
# 5/5 [==============================] - 72s 17s/step - loss: 0.0361 - categorical_accuracy: 0.9940 - val_loss: 1.2750 - val_categorical_accuracy: 0.6500
#
# Epoch 00084: saving model to model_init_2022-07-11_234103\model-00084-0.03610-0.99397-1.27496-0.65000.h5
# Epoch 85/100
# 5/5 [==============================] - 78s 18s/step - loss: 0.0261 - categorical_accuracy: 0.9940 - val_loss: 1.2873 - val_categorical_accuracy: 0.6800
#
# Epoch 00085: saving model to model_init_2022-07-11_234103\model-00085-0.02609-0.99397-1.28728-0.68000.h5
# Epoch 86/100
# 5/5 [==============================] - 74s 17s/step - loss: 0.0312 - categorical_accuracy: 0.9970 - val_loss: 1.2445 - val_categorical_accuracy: 0.6800
#
# Epoch 00086: saving model to model_init_2022-07-11_234103\model-00086-0.03118-0.99698-1.24450-0.68000.h5
# Epoch 87/100
# 5/5 [==============================] - 74s 17s/step - loss: 0.0212 - categorical_accuracy: 0.9985 - val_loss: 1.4027 - val_categorical_accuracy: 0.6300
#
# Epoch 00087: saving model to model_init_2022-07-11_234103\model-00087-0.02118-0.99849-1.40271-0.63000.h5
# Epoch 88/100
# 5/5 [==============================] - 73s 17s/step - loss: 0.0162 - categorical_accuracy: 1.0000 - val_loss: 1.4106 - val_categorical_accuracy: 0.6800
#
# Epoch 00088: saving model to model_init_2022-07-11_234103\model-00088-0.01616-1.00000-1.41058-0.68000.h5
# Epoch 89/100
# 5/5 [==============================] - 75s 17s/step - loss: 0.0155 - categorical_accuracy: 1.0000 - val_loss: 1.4057 - val_categorical_accuracy: 0.6700
#
# Epoch 00089: saving model to model_init_2022-07-11_234103\model-00089-0.01551-1.00000-1.40570-0.67000.h5
# Epoch 90/100
# 5/5 [==============================] - 77s 18s/step - loss: 0.0126 - categorical_accuracy: 1.0000 - val_loss: 1.4097 - val_categorical_accuracy: 0.6700
#
# Epoch 00090: saving model to model_init_2022-07-11_234103\model-00090-0.01263-1.00000-1.40969-0.67000.h5
# Epoch 91/100
# 5/5 [==============================] - 77s 17s/step - loss: 0.0121 - categorical_accuracy: 1.0000 - val_loss: 1.3882 - val_categorical_accuracy: 0.6800
#
# Epoch 00091: saving model to model_init_2022-07-11_234103\model-00091-0.01208-1.00000-1.38822-0.68000.h5
# Epoch 92/100
# 5/5 [==============================] - 78s 18s/step - loss: 0.0105 - categorical_accuracy: 1.0000 - val_loss: 1.3837 - val_categorical_accuracy: 0.6900
#
# Epoch 00092: saving model to model_init_2022-07-11_234103\model-00092-0.01047-1.00000-1.38368-0.69000.h5
# Epoch 93/100
# 5/5 [==============================] - 75s 17s/step - loss: 0.0112 - categorical_accuracy: 1.0000 - val_loss: 1.3920 - val_categorical_accuracy: 0.6900
#
# Epoch 00093: saving model to model_init_2022-07-11_234103\model-00093-0.01116-1.00000-1.39205-0.69000.h5
# Epoch 94/100
# 5/5 [==============================] - 77s 17s/step - loss: 0.0098 - categorical_accuracy: 1.0000 - val_loss: 1.4041 - val_categorical_accuracy: 0.7000
#
# Epoch 00094: saving model to model_init_2022-07-11_234103\model-00094-0.00982-1.00000-1.40407-0.70000.h5
# Epoch 95/100
# 5/5 [==============================] - 75s 17s/step - loss: 0.0098 - categorical_accuracy: 1.0000 - val_loss: 1.4135 - val_categorical_accuracy: 0.7000
#
# Epoch 00095: saving model to model_init_2022-07-11_234103\model-00095-0.00980-1.00000-1.41346-0.70000.h5
# Epoch 96/100
# 5/5 [==============================] - 73s 17s/step - loss: 0.0093 - categorical_accuracy: 1.0000 - val_loss: 1.4219 - val_categorical_accuracy: 0.7000
#
# Epoch 00096: saving model to model_init_2022-07-11_234103\model-00096-0.00934-1.00000-1.42190-0.70000.h5
# Epoch 97/100
# 5/5 [==============================] - 74s 17s/step - loss: 0.0088 - categorical_accuracy: 1.0000 - val_loss: 1.4271 - val_categorical_accuracy: 0.7000
#
# Epoch 00097: saving model to model_init_2022-07-11_234103\model-00097-0.00883-1.00000-1.42712-0.70000.h5
# Epoch 98/100
# 5/5 [==============================] - 73s 17s/step - loss: 0.0090 - categorical_accuracy: 1.0000 - val_loss: 1.4312 - val_categorical_accuracy: 0.7000
#
# Epoch 00098: saving model to model_init_2022-07-11_234103\model-00098-0.00904-1.00000-1.43119-0.70000.h5
# Epoch 99/100
# 5/5 [==============================] - 73s 17s/step - loss: 0.0083 - categorical_accuracy: 1.0000 - val_loss: 1.4339 - val_categorical_accuracy: 0.7000
#
# Epoch 00099: saving model to model_init_2022-07-11_234103\model-00099-0.00831-1.00000-1.43389-0.70000.h5
# Epoch 100/100
# 5/5 [==============================] - 72s 16s/step - loss: 0.0085 - categorical_accuracy: 1.0000 - val_loss: 1.4377 - val_categorical_accuracy: 0.7000
#
# Epoch 00100: saving model to model_init_2022-07-11_234103\model-00100-0.00849-1.00000-1.43769-0.70000.h5

# %%
model_history.history.keys()
# Out:
# dict_keys(['loss', 'categorical_accuracy', 'val_loss', 'val_categorical_accuracy', 'lr'])

# %%
 accuracy_loss_plt(model_history)

# %% [markdown]
# ## Conv2D + LSTM model : Adding Dropout Layer

# %%
# Overfitting on training data -> model not doing good on validation data over the epochs
# Adding Dropout layers to the model

# %%
#### Adding dropout layer to the model

model = Sequential()

model.add(TimeDistributed(Conv2D(16, (3, 3), padding='same',activation = 'relu'),input_shape = (15, 100, 100, 3)))
model.add(TimeDistributed(MaxPooling2D((4, 4)))) 
model.add(TimeDistributed(Dropout(0.25)))

model.add(TimeDistributed(Conv2D(32, (3, 3), padding='same',activation = 'relu')))
model.add(TimeDistributed(MaxPooling2D((4, 4))))
model.add(TimeDistributed(Dropout(0.25)))
    
model.add(TimeDistributed(Conv2D(64, (3, 3), padding='same',activation = 'relu')))
model.add(TimeDistributed(MaxPooling2D((2, 2))))
model.add(TimeDistributed(Dropout(0.25)))
    
model.add(TimeDistributed(Conv2D(64, (3, 3), padding='same',activation = 'relu')))
model.add(TimeDistributed(MaxPooling2D((2, 2))))
model.add(TimeDistributed(Dropout(0.25)))
                                      
model.add(TimeDistributed(Flatten()))
                                      
model.add(LSTM(32))
                                      
model.add(Dense(class_label, activation = 'softmax'))

# %%
optimiser = 'adam' #write your optimizer
model.compile(optimizer=optimiser, loss='categorical_crossentropy', metrics=['categorical_accuracy'])
print (model.summary())
# Out:
# Model: "sequential_1"
# _________________________________________________________________
# Layer (type)                 Output Shape              Param #
# =================================================================
# time_distributed_9 (TimeDist (None, 15, 100, 100, 16)  448
# _________________________________________________________________
# time_distributed_10 (TimeDis (None, 15, 25, 25, 16)    0
# _________________________________________________________________
# time_distributed_11 (TimeDis (None, 15, 25, 25, 16)    0
# _________________________________________________________________
# time_distributed_12 (TimeDis (None, 15, 25, 25, 32)    4640
# _________________________________________________________________
# time_distributed_13 (TimeDis (None, 15, 6, 6, 32)      0
# _________________________________________________________________
# time_distributed_14 (TimeDis (None, 15, 6, 6, 32)      0
# _________________________________________________________________
# time_distributed_15 (TimeDis (None, 15, 6, 6, 64)      18496
# _________________________________________________________________
# time_distributed_16 (TimeDis (None, 15, 3, 3, 64)      0
# _________________________________________________________________
# time_distributed_17 (TimeDis (None, 15, 3, 3, 64)      0
# _________________________________________________________________
# time_distributed_18 (TimeDis (None, 15, 3, 3, 64)      36928
# _________________________________________________________________
# time_distributed_19 (TimeDis (None, 15, 1, 1, 64)      0
# _________________________________________________________________
# time_distributed_20 (TimeDis (None, 15, 1, 1, 64)      0
# _________________________________________________________________
# time_distributed_21 (TimeDis (None, 15, 64)            0
# _________________________________________________________________
# lstm_1 (LSTM)                (None, 32)                12416
# _________________________________________________________________
# dense_1 (Dense)              (None, 5)                 165
# =================================================================
# Total params: 73,093
# Trainable params: 73,093
# Non-trainable params: 0
# _________________________________________________________________
# None

# %%
model_history = model.fit_generator(train_generator, steps_per_epoch=steps_per_epoch, epochs=num_epochs, verbose=1, 
                    callbacks=callbacks_list, validation_data=val_generator, 
                    validation_steps=validation_steps, class_weight=None, workers=1, initial_epoch=0)
# Out:
# Epoch 1/100
# 5/5 [==============================] - 92s 21s/step - loss: 1.6241 - categorical_accuracy: 0.1961 - val_loss: 1.6074 - val_categorical_accuracy: 0.1800
#
# Epoch 00001: saving model to model_init_2022-07-11_234103\model-00001-1.62412-0.19608-1.60740-0.18000.h5
# Epoch 2/100
# 5/5 [==============================] - 85s 21s/step - loss: 1.6046 - categorical_accuracy: 0.1961 - val_loss: 1.6021 - val_categorical_accuracy: 0.2100
#
# Epoch 00002: saving model to model_init_2022-07-11_234103\model-00002-1.60459-0.19608-1.60212-0.21000.h5
# Epoch 3/100
# 5/5 [==============================] - 82s 20s/step - loss: 1.5944 - categorical_accuracy: 0.2805 - val_loss: 1.5990 - val_categorical_accuracy: 0.2400
#
# Epoch 00003: saving model to model_init_2022-07-11_234103\model-00003-1.59438-0.28054-1.59896-0.24000.h5
# Epoch 4/100
# 5/5 [==============================] - 82s 20s/step - loss: 1.5835 - categorical_accuracy: 0.2624 - val_loss: 1.5943 - val_categorical_accuracy: 0.2700
#
# Epoch 00004: saving model to model_init_2022-07-11_234103\model-00004-1.58346-0.26244-1.59433-0.27000.h5
# Epoch 5/100
# 5/5 [==============================] - 81s 20s/step - loss: 1.5732 - categorical_accuracy: 0.2790 - val_loss: 1.5838 - val_categorical_accuracy: 0.2200
#
# Epoch 00005: saving model to model_init_2022-07-11_234103\model-00005-1.57322-0.27903-1.58383-0.22000.h5
# Epoch 6/100
# 5/5 [==============================] - 80s 19s/step - loss: 1.5527 - categorical_accuracy: 0.3167 - val_loss: 1.5575 - val_categorical_accuracy: 0.3400
#
# Epoch 00006: saving model to model_init_2022-07-11_234103\model-00006-1.55272-0.31674-1.55750-0.34000.h5
# Epoch 7/100
# 5/5 [==============================] - 81s 20s/step - loss: 1.4981 - categorical_accuracy: 0.3484 - val_loss: 1.5205 - val_categorical_accuracy: 0.3600
#
# Epoch 00007: saving model to model_init_2022-07-11_234103\model-00007-1.49813-0.34842-1.52053-0.36000.h5
# Epoch 8/100
# 5/5 [==============================] - 83s 20s/step - loss: 1.4785 - categorical_accuracy: 0.3228 - val_loss: 1.4929 - val_categorical_accuracy: 0.3200
#
# Epoch 00008: saving model to model_init_2022-07-11_234103\model-00008-1.47851-0.32278-1.49288-0.32000.h5
# Epoch 9/100
# 5/5 [==============================] - 80s 19s/step - loss: 1.4631 - categorical_accuracy: 0.3605 - val_loss: 1.4511 - val_categorical_accuracy: 0.3900
#
# Epoch 00009: saving model to model_init_2022-07-11_234103\model-00009-1.46307-0.36048-1.45112-0.39000.h5
# Epoch 10/100
# 5/5 [==============================] - 82s 20s/step - loss: 1.4379 - categorical_accuracy: 0.3680 - val_loss: 1.5952 - val_categorical_accuracy: 0.3300
#
# Epoch 00010: saving model to model_init_2022-07-11_234103\model-00010-1.43795-0.36802-1.59515-0.33000.h5
# Epoch 11/100
# 5/5 [==============================] - 98s 24s/step - loss: 1.3956 - categorical_accuracy: 0.3906 - val_loss: 1.5271 - val_categorical_accuracy: 0.2900
#
# Epoch 00011: saving model to model_init_2022-07-11_234103\model-00011-1.39564-0.39065-1.52708-0.29000.h5
# Epoch 12/100
# 5/5 [==============================] - 81s 20s/step - loss: 1.3437 - categorical_accuracy: 0.4193 - val_loss: 1.4989 - val_categorical_accuracy: 0.3400
#
# Epoch 00012: saving model to model_init_2022-07-11_234103\model-00012-1.34374-0.41931-1.49888-0.34000.h5
# Epoch 13/100
# 5/5 [==============================] - 77s 19s/step - loss: 1.3224 - categorical_accuracy: 0.4480 - val_loss: 1.5383 - val_categorical_accuracy: 0.3100
#
# Epoch 00013: saving model to model_init_2022-07-11_234103\model-00013-1.32240-0.44796-1.53829-0.31000.h5
# Epoch 14/100
# 5/5 [==============================] - 79s 19s/step - loss: 1.2412 - categorical_accuracy: 0.5008 - val_loss: 1.5556 - val_categorical_accuracy: 0.2900
#
# Epoch 00014: saving model to model_init_2022-07-11_234103\model-00014-1.24125-0.50075-1.55557-0.29000.h5
# Epoch 15/100
# 5/5 [==============================] - 77s 18s/step - loss: 1.2229 - categorical_accuracy: 0.4962 - val_loss: 1.8090 - val_categorical_accuracy: 0.2900
#
# Epoch 00015: saving model to model_init_2022-07-11_234103\model-00015-1.22295-0.49623-1.80897-0.29000.h5
# Epoch 16/100
# 5/5 [==============================] - 131s 32s/step - loss: 1.1979 - categorical_accuracy: 0.5249 - val_loss: 1.5618 - val_categorical_accuracy: 0.3000
#
# Epoch 00016: saving model to model_init_2022-07-11_234103\model-00016-1.19794-0.52489-1.56182-0.30000.h5
# Epoch 17/100
# 5/5 [==============================] - 87s 21s/step - loss: 1.1524 - categorical_accuracy: 0.5370 - val_loss: 1.6518 - val_categorical_accuracy: 0.2900
#
# Epoch 00017: saving model to model_init_2022-07-11_234103\model-00017-1.15244-0.53695-1.65175-0.29000.h5
# Epoch 18/100
# 5/5 [==============================] - 92s 22s/step - loss: 1.1703 - categorical_accuracy: 0.5204 - val_loss: 1.6406 - val_categorical_accuracy: 0.2800
#
# Epoch 00018: saving model to model_init_2022-07-11_234103\model-00018-1.17029-0.52036-1.64064-0.28000.h5
# Epoch 19/100
# 5/5 [==============================] - 88s 21s/step - loss: 1.1088 - categorical_accuracy: 0.5566 - val_loss: 1.5511 - val_categorical_accuracy: 0.3000
#
# Epoch 00019: saving model to model_init_2022-07-11_234103\model-00019-1.10882-0.55656-1.55105-0.30000.h5
# Epoch 20/100
# 5/5 [==============================] - 89s 21s/step - loss: 1.0574 - categorical_accuracy: 0.5671 - val_loss: 1.7074 - val_categorical_accuracy: 0.2900
#
# Epoch 00020: saving model to model_init_2022-07-11_234103\model-00020-1.05740-0.56712-1.70741-0.29000.h5
# Epoch 21/100
# 5/5 [==============================] - 89s 21s/step - loss: 1.1025 - categorical_accuracy: 0.5716 - val_loss: 1.5818 - val_categorical_accuracy: 0.3400
#
# Epoch 00021: saving model to model_init_2022-07-11_234103\model-00021-1.10251-0.57164-1.58182-0.34000.h5
# Epoch 22/100
# 5/5 [==============================] - 98s 24s/step - loss: 1.0729 - categorical_accuracy: 0.5566 - val_loss: 1.4848 - val_categorical_accuracy: 0.3800
#
# Epoch 00022: saving model to model_init_2022-07-11_234103\model-00022-1.07294-0.55656-1.48476-0.38000.h5
# Epoch 23/100
# 5/5 [==============================] - 85s 20s/step - loss: 1.0467 - categorical_accuracy: 0.5913 - val_loss: 1.5849 - val_categorical_accuracy: 0.3400
#
# Epoch 00023: saving model to model_init_2022-07-11_234103\model-00023-1.04666-0.59125-1.58494-0.34000.h5
# Epoch 24/100
# 5/5 [==============================] - 87s 21s/step - loss: 0.9716 - categorical_accuracy: 0.6214 - val_loss: 1.4902 - val_categorical_accuracy: 0.3800
#
# Epoch 00024: saving model to model_init_2022-07-11_234103\model-00024-0.97164-0.62142-1.49021-0.38000.h5
# Epoch 25/100
# 5/5 [==============================] - 82s 20s/step - loss: 0.9536 - categorical_accuracy: 0.6169 - val_loss: 1.3324 - val_categorical_accuracy: 0.4500
#
# Epoch 00025: saving model to model_init_2022-07-11_234103\model-00025-0.95362-0.61689-1.33244-0.45000.h5
# Epoch 26/100
# 5/5 [==============================] - 97s 23s/step - loss: 0.9262 - categorical_accuracy: 0.6440 - val_loss: 1.4958 - val_categorical_accuracy: 0.3800
#
# Epoch 00026: saving model to model_init_2022-07-11_234103\model-00026-0.92624-0.64404-1.49585-0.38000.h5
# Epoch 27/100
# 5/5 [==============================] - 105s 25s/step - loss: 0.8938 - categorical_accuracy: 0.6501 - val_loss: 1.3925 - val_categorical_accuracy: 0.4500
#
# Epoch 00027: saving model to model_init_2022-07-11_234103\model-00027-0.89384-0.65008-1.39247-0.45000.h5
# Epoch 28/100
# 5/5 [==============================] - 92s 22s/step - loss: 0.9140 - categorical_accuracy: 0.6501 - val_loss: 1.5397 - val_categorical_accuracy: 0.3800
#
# Epoch 00028: saving model to model_init_2022-07-11_234103\model-00028-0.91400-0.65008-1.53974-0.38000.h5
# Epoch 29/100
# 5/5 [==============================] - 99s 24s/step - loss: 0.9197 - categorical_accuracy: 0.6410 - val_loss: 1.2896 - val_categorical_accuracy: 0.4900
#
# Epoch 00029: saving model to model_init_2022-07-11_234103\model-00029-0.91968-0.64103-1.28958-0.49000.h5
# Epoch 30/100
# 5/5 [==============================] - 93s 22s/step - loss: 0.8389 - categorical_accuracy: 0.6727 - val_loss: 1.1007 - val_categorical_accuracy: 0.5800
#
# Epoch 00030: saving model to model_init_2022-07-11_234103\model-00030-0.83891-0.67270-1.10066-0.58000.h5
# Epoch 31/100
# 5/5 [==============================] - 102s 24s/step - loss: 0.8856 - categorical_accuracy: 0.6456 - val_loss: 1.2103 - val_categorical_accuracy: 0.5300
#
# Epoch 00031: saving model to model_init_2022-07-11_234103\model-00031-0.88560-0.64555-1.21033-0.53000.h5
# Epoch 32/100
# 5/5 [==============================] - 105s 25s/step - loss: 0.8290 - categorical_accuracy: 0.6652 - val_loss: 1.2639 - val_categorical_accuracy: 0.4900
#
# Epoch 00032: saving model to model_init_2022-07-11_234103\model-00032-0.82899-0.66516-1.26386-0.49000.h5
# Epoch 33/100
# 5/5 [==============================] - 117s 28s/step - loss: 0.7754 - categorical_accuracy: 0.7074 - val_loss: 1.2620 - val_categorical_accuracy: 0.5100
#
# Epoch 00033: saving model to model_init_2022-07-11_234103\model-00033-0.77543-0.70739-1.26202-0.51000.h5
# Epoch 34/100
# 5/5 [==============================] - 98s 23s/step - loss: 0.7880 - categorical_accuracy: 0.6893 - val_loss: 1.1532 - val_categorical_accuracy: 0.5400
#
# Epoch 00034: saving model to model_init_2022-07-11_234103\model-00034-0.78799-0.68929-1.15321-0.54000.h5
# Epoch 35/100
# 5/5 [==============================] - 93s 22s/step - loss: 0.7470 - categorical_accuracy: 0.7044 - val_loss: 1.3545 - val_categorical_accuracy: 0.4600
#
# Epoch 00035: saving model to model_init_2022-07-11_234103\model-00035-0.74703-0.70437-1.35452-0.46000.h5
# Epoch 36/100
# 5/5 [==============================] - 90s 21s/step - loss: 0.7278 - categorical_accuracy: 0.7255 - val_loss: 1.4091 - val_categorical_accuracy: 0.4700
#
# Epoch 00036: saving model to model_init_2022-07-11_234103\model-00036-0.72778-0.72549-1.40915-0.47000.h5
# Epoch 37/100
# 5/5 [==============================] - 90s 22s/step - loss: 0.7392 - categorical_accuracy: 0.7210 - val_loss: 1.2110 - val_categorical_accuracy: 0.5700
#
# Epoch 00037: saving model to model_init_2022-07-11_234103\model-00037-0.73919-0.72097-1.21102-0.57000.h5
# Epoch 38/100
# 5/5 [==============================] - 95s 23s/step - loss: 0.7189 - categorical_accuracy: 0.7210 - val_loss: 1.3602 - val_categorical_accuracy: 0.5200
#
# Epoch 00038: saving model to model_init_2022-07-11_234103\model-00038-0.71892-0.72097-1.36015-0.52000.h5
# Epoch 39/100
# 5/5 [==============================] - 93s 22s/step - loss: 0.6597 - categorical_accuracy: 0.7481 - val_loss: 1.2887 - val_categorical_accuracy: 0.5200
#
# Epoch 00039: saving model to model_init_2022-07-11_234103\model-00039-0.65969-0.74811-1.28865-0.52000.h5
# Epoch 40/100
# 5/5 [==============================] - 92s 22s/step - loss: 0.7399 - categorical_accuracy: 0.7270 - val_loss: 1.1479 - val_categorical_accuracy: 0.5800
#
# Epoch 00040: saving model to model_init_2022-07-11_234103\model-00040-0.73991-0.72700-1.14787-0.58000.h5
# Epoch 41/100
# 5/5 [==============================] - 93s 22s/step - loss: 0.6715 - categorical_accuracy: 0.7300 - val_loss: 1.1884 - val_categorical_accuracy: 0.5400
#
# Epoch 00041: saving model to model_init_2022-07-11_234103\model-00041-0.67151-0.73002-1.18838-0.54000.h5
# Epoch 42/100
# 5/5 [==============================] - 98s 23s/step - loss: 0.6846 - categorical_accuracy: 0.7511 - val_loss: 1.2464 - val_categorical_accuracy: 0.5300
#
# Epoch 00042: saving model to model_init_2022-07-11_234103\model-00042-0.68464-0.75113-1.24642-0.53000.h5
# Epoch 43/100
# 5/5 [==============================] - 95s 23s/step - loss: 0.6137 - categorical_accuracy: 0.7768 - val_loss: 1.4547 - val_categorical_accuracy: 0.4800
#
# Epoch 00043: saving model to model_init_2022-07-11_234103\model-00043-0.61370-0.77677-1.45470-0.48000.h5
# Epoch 44/100
# 5/5 [==============================] - 93s 22s/step - loss: 0.6230 - categorical_accuracy: 0.7632 - val_loss: 1.0586 - val_categorical_accuracy: 0.5900
#
# Epoch 00044: saving model to model_init_2022-07-11_234103\model-00044-0.62297-0.76320-1.05860-0.59000.h5
# Epoch 45/100
# 5/5 [==============================] - 101s 24s/step - loss: 0.6086 - categorical_accuracy: 0.7662 - val_loss: 0.9582 - val_categorical_accuracy: 0.6000
#
# Epoch 00045: saving model to model_init_2022-07-11_234103\model-00045-0.60858-0.76621-0.95820-0.60000.h5
# Epoch 46/100
# 5/5 [==============================] - 94s 22s/step - loss: 0.5565 - categorical_accuracy: 0.7964 - val_loss: 0.9978 - val_categorical_accuracy: 0.5900
#
# Epoch 00046: saving model to model_init_2022-07-11_234103\model-00046-0.55654-0.79638-0.99779-0.59000.h5
# Epoch 47/100
# 5/5 [==============================] - 86s 20s/step - loss: 0.5873 - categorical_accuracy: 0.7934 - val_loss: 1.0372 - val_categorical_accuracy: 0.5800
#
# Epoch 00047: saving model to model_init_2022-07-11_234103\model-00047-0.58733-0.79336-1.03724-0.58000.h5
# Epoch 48/100
# 5/5 [==============================] - 92s 22s/step - loss: 0.5234 - categorical_accuracy: 0.7979 - val_loss: 1.0882 - val_categorical_accuracy: 0.5700
#
# Epoch 00048: saving model to model_init_2022-07-11_234103\model-00048-0.52339-0.79789-1.08824-0.57000.h5
# Epoch 49/100
# 5/5 [==============================] - 88s 21s/step - loss: 0.5145 - categorical_accuracy: 0.8190 - val_loss: 1.1776 - val_categorical_accuracy: 0.5600
#
# Epoch 00049: saving model to model_init_2022-07-11_234103\model-00049-0.51446-0.81900-1.17765-0.56000.h5
# Epoch 50/100
# 5/5 [==============================] - 87s 21s/step - loss: 0.5877 - categorical_accuracy: 0.7843 - val_loss: 1.5380 - val_categorical_accuracy: 0.4500
#
# Epoch 00050: saving model to model_init_2022-07-11_234103\model-00050-0.58767-0.78431-1.53802-0.45000.h5
# Epoch 51/100
# 5/5 [==============================] - 75s 18s/step - loss: 0.5350 - categorical_accuracy: 0.8069 - val_loss: 1.1548 - val_categorical_accuracy: 0.5300
#
# Epoch 00051: saving model to model_init_2022-07-11_234103\model-00051-0.53504-0.80694-1.15482-0.53000.h5
# Epoch 52/100
# 5/5 [==============================] - 72s 17s/step - loss: 0.5331 - categorical_accuracy: 0.7828 - val_loss: 0.9620 - val_categorical_accuracy: 0.6200
#
# Epoch 00052: saving model to model_init_2022-07-11_234103\model-00052-0.53309-0.78281-0.96198-0.62000.h5
# Epoch 53/100
# 5/5 [==============================] - 81s 19s/step - loss: 0.4790 - categorical_accuracy: 0.8341 - val_loss: 0.9260 - val_categorical_accuracy: 0.6400
#
# Epoch 00053: saving model to model_init_2022-07-11_234103\model-00053-0.47897-0.83409-0.92600-0.64000.h5
# Epoch 54/100
# 5/5 [==============================] - 70s 17s/step - loss: 0.4758 - categorical_accuracy: 0.8311 - val_loss: 1.2508 - val_categorical_accuracy: 0.5700
#
# Epoch 00054: saving model to model_init_2022-07-11_234103\model-00054-0.47580-0.83107-1.25082-0.57000.h5
# Epoch 55/100
# 5/5 [==============================] - 70s 17s/step - loss: 0.4245 - categorical_accuracy: 0.8386 - val_loss: 1.0523 - val_categorical_accuracy: 0.6300
#
# Epoch 00055: saving model to model_init_2022-07-11_234103\model-00055-0.42447-0.83861-1.05228-0.63000.h5
# Epoch 56/100
# 5/5 [==============================] - 71s 17s/step - loss: 0.4579 - categorical_accuracy: 0.8446 - val_loss: 1.1924 - val_categorical_accuracy: 0.5900
#
# Epoch 00056: saving model to model_init_2022-07-11_234103\model-00056-0.45789-0.84465-1.19243-0.59000.h5
# Epoch 57/100
# 5/5 [==============================] - 74s 18s/step - loss: 0.3980 - categorical_accuracy: 0.8643 - val_loss: 0.9607 - val_categorical_accuracy: 0.6200
#
# Epoch 00057: saving model to model_init_2022-07-11_234103\model-00057-0.39802-0.86425-0.96071-0.62000.h5
# Epoch 58/100
# 5/5 [==============================] - 66s 16s/step - loss: 0.3582 - categorical_accuracy: 0.8869 - val_loss: 1.1218 - val_categorical_accuracy: 0.6100
#
# Epoch 00058: saving model to model_init_2022-07-11_234103\model-00058-0.35817-0.88688-1.12183-0.61000.h5
# Epoch 59/100
# 5/5 [==============================] - 65s 16s/step - loss: 0.3422 - categorical_accuracy: 0.8703 - val_loss: 1.0112 - val_categorical_accuracy: 0.6400
#
# Epoch 00059: saving model to model_init_2022-07-11_234103\model-00059-0.34223-0.87029-1.01117-0.64000.h5
# Epoch 60/100
# 5/5 [==============================] - 59s 14s/step - loss: 0.3542 - categorical_accuracy: 0.8718 - val_loss: 1.0237 - val_categorical_accuracy: 0.6700
#
# Epoch 00060: saving model to model_init_2022-07-11_234103\model-00060-0.35418-0.87179-1.02367-0.67000.h5
# Epoch 61/100
# 5/5 [==============================] - 53s 13s/step - loss: 0.3251 - categorical_accuracy: 0.8748 - val_loss: 1.0712 - val_categorical_accuracy: 0.6200
#
# Epoch 00061: saving model to model_init_2022-07-11_234103\model-00061-0.32514-0.87481-1.07118-0.62000.h5
# Epoch 62/100
# 5/5 [==============================] - 25640s 6409s/step - loss: 0.3097 - categorical_accuracy: 0.8974 - val_loss: 1.0965 - val_categorical_accuracy: 0.6200
#
# Epoch 00062: saving model to model_init_2022-07-11_234103\model-00062-0.30966-0.89744-1.09651-0.62000.h5
# Epoch 63/100
# 5/5 [==============================] - 54s 13s/step - loss: 0.4312 - categorical_accuracy: 0.8431 - val_loss: 0.9400 - val_categorical_accuracy: 0.6600
#
# Epoch 00063: saving model to model_init_2022-07-11_234103\model-00063-0.43121-0.84314-0.94004-0.66000.h5
# Epoch 64/100
# 5/5 [==============================] - 56s 14s/step - loss: 0.3672 - categorical_accuracy: 0.8718 - val_loss: 0.7963 - val_categorical_accuracy: 0.6900
#
# Epoch 00064: saving model to model_init_2022-07-11_234103\model-00064-0.36717-0.87179-0.79625-0.69000.h5
# Epoch 65/100
# 5/5 [==============================] - 54s 13s/step - loss: 0.2958 - categorical_accuracy: 0.8974 - val_loss: 1.1486 - val_categorical_accuracy: 0.6200
#
# Epoch 00065: saving model to model_init_2022-07-11_234103\model-00065-0.29580-0.89744-1.14858-0.62000.h5
# Epoch 66/100
# 5/5 [==============================] - 53s 13s/step - loss: 0.3642 - categorical_accuracy: 0.8627 - val_loss: 0.8974 - val_categorical_accuracy: 0.6600
#
# Epoch 00066: saving model to model_init_2022-07-11_234103\model-00066-0.36419-0.86275-0.89740-0.66000.h5
# Epoch 67/100
# 5/5 [==============================] - 50s 12s/step - loss: 0.3059 - categorical_accuracy: 0.8884 - val_loss: 0.9641 - val_categorical_accuracy: 0.6500
#
# Epoch 00067: saving model to model_init_2022-07-11_234103\model-00067-0.30589-0.88839-0.96413-0.65000.h5
# Epoch 68/100
# 5/5 [==============================] - 55s 13s/step - loss: 0.2773 - categorical_accuracy: 0.9050 - val_loss: 0.9316 - val_categorical_accuracy: 0.6600
#
# Epoch 00068: saving model to model_init_2022-07-11_234103\model-00068-0.27729-0.90498-0.93157-0.66000.h5
# Epoch 69/100
# 5/5 [==============================] - 53s 13s/step - loss: 0.2797 - categorical_accuracy: 0.9095 - val_loss: 0.9013 - val_categorical_accuracy: 0.7000
#
# Epoch 00069: saving model to model_init_2022-07-11_234103\model-00069-0.27966-0.90950-0.90126-0.70000.h5
# Epoch 70/100
# 5/5 [==============================] - 54s 13s/step - loss: 0.2401 - categorical_accuracy: 0.9231 - val_loss: 1.0176 - val_categorical_accuracy: 0.6800
#
# Epoch 00070: saving model to model_init_2022-07-11_234103\model-00070-0.24013-0.92308-1.01756-0.68000.h5
# Epoch 71/100
# 5/5 [==============================] - 51s 12s/step - loss: 0.2411 - categorical_accuracy: 0.9125 - val_loss: 0.7907 - val_categorical_accuracy: 0.7400
#
# Epoch 00071: saving model to model_init_2022-07-11_234103\model-00071-0.24114-0.91252-0.79073-0.74000.h5
# Epoch 72/100
# 5/5 [==============================] - 70s 17s/step - loss: 0.2889 - categorical_accuracy: 0.9110 - val_loss: 1.0708 - val_categorical_accuracy: 0.6600
#
# Epoch 00072: saving model to model_init_2022-07-11_234103\model-00072-0.28888-0.91101-1.07080-0.66000.h5
# Epoch 73/100
# 5/5 [==============================] - 82s 20s/step - loss: 0.2089 - categorical_accuracy: 0.9321 - val_loss: 0.9904 - val_categorical_accuracy: 0.6800
#
# Epoch 00073: saving model to model_init_2022-07-11_234103\model-00073-0.20890-0.93213-0.99040-0.68000.h5
# Epoch 74/100
# 5/5 [==============================] - 80s 19s/step - loss: 0.2350 - categorical_accuracy: 0.9155 - val_loss: 0.9037 - val_categorical_accuracy: 0.6700
#
# Epoch 00074: saving model to model_init_2022-07-11_234103\model-00074-0.23498-0.91554-0.90370-0.67000.h5
# Epoch 75/100
# 5/5 [==============================] - 76s 18s/step - loss: 0.1826 - categorical_accuracy: 0.9548 - val_loss: 0.9483 - val_categorical_accuracy: 0.7000
#
# Epoch 00075: saving model to model_init_2022-07-11_234103\model-00075-0.18261-0.95475-0.94834-0.70000.h5
# Epoch 76/100
# 5/5 [==============================] - 74s 18s/step - loss: 0.2015 - categorical_accuracy: 0.9351 - val_loss: 1.0633 - val_categorical_accuracy: 0.6700
#
# Epoch 00076: saving model to model_init_2022-07-11_234103\model-00076-0.20155-0.93514-1.06334-0.67000.h5
# Epoch 77/100
# 5/5 [==============================] - 80s 19s/step - loss: 0.1697 - categorical_accuracy: 0.9548 - val_loss: 1.0827 - val_categorical_accuracy: 0.6600
#
# Epoch 00077: saving model to model_init_2022-07-11_234103\model-00077-0.16972-0.95475-1.08270-0.66000.h5
# Epoch 78/100
# 5/5 [==============================] - 94s 23s/step - loss: 0.1478 - categorical_accuracy: 0.9653 - val_loss: 0.9987 - val_categorical_accuracy: 0.6700
#
# Epoch 00078: saving model to model_init_2022-07-11_234103\model-00078-0.14779-0.96531-0.99872-0.67000.h5
# Epoch 79/100
# 5/5 [==============================] - 80s 19s/step - loss: 0.1397 - categorical_accuracy: 0.9608 - val_loss: 1.0878 - val_categorical_accuracy: 0.6500
#
# Epoch 00079: saving model to model_init_2022-07-11_234103\model-00079-0.13965-0.96078-1.08778-0.65000.h5
# Epoch 80/100
# 5/5 [==============================] - 79s 19s/step - loss: 0.1566 - categorical_accuracy: 0.9502 - val_loss: 0.9159 - val_categorical_accuracy: 0.7100
#
# Epoch 00080: saving model to model_init_2022-07-11_234103\model-00080-0.15658-0.95023-0.91592-0.71000.h5
# Epoch 81/100
# 5/5 [==============================] - 80s 19s/step - loss: 0.1190 - categorical_accuracy: 0.9653 - val_loss: 1.0547 - val_categorical_accuracy: 0.6900
#
# Epoch 00081: saving model to model_init_2022-07-11_234103\model-00081-0.11896-0.96531-1.05466-0.69000.h5
# Epoch 82/100
# 5/5 [==============================] - 77s 18s/step - loss: 0.1240 - categorical_accuracy: 0.9653 - val_loss: 0.9314 - val_categorical_accuracy: 0.7000
#
# Epoch 00082: saving model to model_init_2022-07-11_234103\model-00082-0.12398-0.96531-0.93138-0.70000.h5
# Epoch 83/100
# 5/5 [==============================] - 77s 19s/step - loss: 0.1282 - categorical_accuracy: 0.9563 - val_loss: 1.0776 - val_categorical_accuracy: 0.6900
#
# Epoch 00083: saving model to model_init_2022-07-11_234103\model-00083-0.12818-0.95626-1.07763-0.69000.h5
# Epoch 84/100
# 5/5 [==============================] - 73s 18s/step - loss: 0.1448 - categorical_accuracy: 0.9593 - val_loss: 1.0295 - val_categorical_accuracy: 0.6700
#
# Epoch 00084: saving model to model_init_2022-07-11_234103\model-00084-0.14484-0.95928-1.02950-0.67000.h5
# Epoch 85/100
# 5/5 [==============================] - 75s 18s/step - loss: 0.1510 - categorical_accuracy: 0.9517 - val_loss: 1.1115 - val_categorical_accuracy: 0.6800
#
# Epoch 00085: saving model to model_init_2022-07-11_234103\model-00085-0.15097-0.95173-1.11149-0.68000.h5
# Epoch 86/100
# 5/5 [==============================] - 76s 18s/step - loss: 0.0998 - categorical_accuracy: 0.9744 - val_loss: 0.9196 - val_categorical_accuracy: 0.7100
#
# Epoch 00086: saving model to model_init_2022-07-11_234103\model-00086-0.09980-0.97436-0.91961-0.71000.h5
# Epoch 87/100
# 5/5 [==============================] - 75s 18s/step - loss: 0.1517 - categorical_accuracy: 0.9502 - val_loss: 0.7686 - val_categorical_accuracy: 0.7000
#
# Epoch 00087: saving model to model_init_2022-07-11_234103\model-00087-0.15175-0.95023-0.76857-0.70000.h5
# Epoch 88/100
# 5/5 [==============================] - 75s 18s/step - loss: 0.1413 - categorical_accuracy: 0.9623 - val_loss: 0.9029 - val_categorical_accuracy: 0.7300
#
# Epoch 00088: saving model to model_init_2022-07-11_234103\model-00088-0.14127-0.96229-0.90290-0.73000.h5
# Epoch 89/100
# 5/5 [==============================] - 78s 19s/step - loss: 0.1051 - categorical_accuracy: 0.9774 - val_loss: 0.9929 - val_categorical_accuracy: 0.6800
#
# Epoch 00089: saving model to model_init_2022-07-11_234103\model-00089-0.10515-0.97738-0.99290-0.68000.h5
# Epoch 90/100
# 5/5 [==============================] - 73s 18s/step - loss: 0.0942 - categorical_accuracy: 0.9759 - val_loss: 1.0744 - val_categorical_accuracy: 0.6900
#
# Epoch 00090: saving model to model_init_2022-07-11_234103\model-00090-0.09421-0.97587-1.07437-0.69000.h5
# Epoch 91/100
# 5/5 [==============================] - 75s 18s/step - loss: 0.0797 - categorical_accuracy: 0.9759 - val_loss: 0.9044 - val_categorical_accuracy: 0.7100
#
# Epoch 00091: saving model to model_init_2022-07-11_234103\model-00091-0.07973-0.97587-0.90442-0.71000.h5
# Epoch 92/100
# 5/5 [==============================] - 76s 18s/step - loss: 0.0806 - categorical_accuracy: 0.9774 - val_loss: 0.9804 - val_categorical_accuracy: 0.7100
#
# Epoch 00092: saving model to model_init_2022-07-11_234103\model-00092-0.08061-0.97738-0.98036-0.71000.h5
# Epoch 93/100
# 5/5 [==============================] - 73s 18s/step - loss: 0.0913 - categorical_accuracy: 0.9713 - val_loss: 0.8922 - val_categorical_accuracy: 0.6900
#
# Epoch 00093: saving model to model_init_2022-07-11_234103\model-00093-0.09130-0.97134-0.89223-0.69000.h5
# Epoch 94/100
# 5/5 [==============================] - 74s 18s/step - loss: 0.0830 - categorical_accuracy: 0.9744 - val_loss: 1.1769 - val_categorical_accuracy: 0.7000
#
# Epoch 00094: saving model to model_init_2022-07-11_234103\model-00094-0.08302-0.97436-1.17689-0.70000.h5
# Epoch 95/100
# 5/5 [==============================] - 73s 18s/step - loss: 0.0773 - categorical_accuracy: 0.9789 - val_loss: 0.9770 - val_categorical_accuracy: 0.6800
#
# Epoch 00095: saving model to model_init_2022-07-11_234103\model-00095-0.07733-0.97888-0.97696-0.68000.h5
# Epoch 96/100
# 5/5 [==============================] - 74s 18s/step - loss: 0.0911 - categorical_accuracy: 0.9774 - val_loss: 1.0406 - val_categorical_accuracy: 0.6800
#
# Epoch 00096: saving model to model_init_2022-07-11_234103\model-00096-0.09108-0.97738-1.04064-0.68000.h5
# Epoch 97/100
# 5/5 [==============================] - 73s 18s/step - loss: 0.0703 - categorical_accuracy: 0.9864 - val_loss: 1.1043 - val_categorical_accuracy: 0.6900
#
# Epoch 00097: saving model to model_init_2022-07-11_234103\model-00097-0.07034-0.98643-1.10430-0.69000.h5
# Epoch 98/100
# 5/5 [==============================] - 77s 19s/step - loss: 0.1389 - categorical_accuracy: 0.9563 - val_loss: 1.3250 - val_categorical_accuracy: 0.6500
#
# Epoch 00098: saving model to model_init_2022-07-11_234103\model-00098-0.13888-0.95626-1.32503-0.65000.h5
# Epoch 99/100
# 5/5 [==============================] - 75s 18s/step - loss: 0.1039 - categorical_accuracy: 0.9638 - val_loss: 1.1517 - val_categorical_accuracy: 0.6600
#
# Epoch 00099: saving model to model_init_2022-07-11_234103\model-00099-0.10388-0.96380-1.15174-0.66000.h5
# Epoch 100/100
# 5/5 [==============================] - 73s 18s/step - loss: 0.1090 - categorical_accuracy: 0.9698 - val_loss: 0.9454 - val_categorical_accuracy: 0.6700
#
# Epoch 00100: saving model to model_init_2022-07-11_234103\model-00100-0.10901-0.96983-0.94537-0.67000.h5

# %%
accuracy_loss_plt(model_history)
# Out:
# best_val_accuracy: 0.7400000095367432
# best_val_loss: 0.7685701251029968

# %% [markdown]
# ## Conv3D Model

# %%
model = Sequential()

model.add(Conv3D(16, kernel_size=3, input_shape=(15, 100, 100, 3)))
model.add(BatchNormalization())
model.add(Activation('relu'))

model.add(Conv3D(32, 3))
model.add(BatchNormalization())
model.add(Activation('relu'))
model.add(MaxPooling3D(pool_size=(2, 2, 2)))
model.add(Flatten())

model.add(BatchNormalization())
model.add(Activation('relu'))
model.add(Dense(class_label, activation='softmax'))

# %%
optimiser = 'adam' #write your optimizer
model.compile(optimizer=optimiser, loss='categorical_crossentropy', metrics=['categorical_accuracy'])
print (model.summary())
# Out:
# Model: "sequential_3"
# _________________________________________________________________
# Layer (type)                 Output Shape              Param #
# =================================================================
# conv3d_6 (Conv3D)            (None, 13, 98, 98, 16)    1312
# _________________________________________________________________
# batch_normalization_9 (Batch (None, 13, 98, 98, 16)    64
# _________________________________________________________________
# activation_9 (Activation)    (None, 13, 98, 98, 16)    0
# _________________________________________________________________
# conv3d_7 (Conv3D)            (None, 11, 96, 96, 32)    13856
# _________________________________________________________________
# batch_normalization_10 (Batc (None, 11, 96, 96, 32)    128
# _________________________________________________________________
# activation_10 (Activation)   (None, 11, 96, 96, 32)    0
# _________________________________________________________________
# max_pooling3d_3 (MaxPooling3 (None, 5, 48, 48, 32)     0
# _________________________________________________________________
# flatten_3 (Flatten)          (None, 368640)            0
# _________________________________________________________________
# batch_normalization_11 (Batc (None, 368640)            1474560
# _________________________________________________________________
# activation_11 (Activation)   (None, 368640)            0
# _________________________________________________________________
# dense_3 (Dense)              (None, 5)                 1843205
# =================================================================
# Total params: 3,333,125
# Trainable params: 2,595,749
# Non-trainable params: 737,376
# _________________________________________________________________
# None

# %% [markdown]
# #### Updating the batch size to 30 as 150 too high for CNN 3D model

# %%
batch_size = 30 
#experiment with the batch size
#300 is too high; 
#failing with 150 

steps_per_epoch = 0

validation_steps = 0

num_train_sequences = len(train_doc)
num_val_sequences = len(val_doc)

if (num_train_sequences%batch_size) == 0:
    steps_per_epoch = int(num_train_sequences/batch_size)
else:
    steps_per_epoch = (num_train_sequences//batch_size) + 1

if (num_val_sequences%batch_size) == 0:
    validation_steps = int(num_val_sequences/batch_size)
else:
    validation_steps = (num_val_sequences//batch_size) + 1
    
print(f'steps_per_epoch: {steps_per_epoch}')
print(f'validation_steps: {validation_steps}')
# Out:
# steps_per_epoch: 23
# validation_steps: 4

# %%
#temporarily changing epoch size to 10

model_history = model.fit_generator(train_generator, steps_per_epoch=steps_per_epoch, epochs=10, verbose=1, 
                    callbacks=callbacks_list, validation_data=val_generator, 
                    validation_steps=validation_steps, class_weight=None, workers=1, initial_epoch=0)
# Out:
# Epoch 1/10
# 23/23 [==============================] - 569s 25s/step - loss: 9.3066 - categorical_accuracy: 0.7934 - val_loss: 10.5437 - val_categorical_accuracy: 0.2100
#
# Epoch 00001: saving model to model_init_2022-07-13_004053\model-00001-9.30658-0.79336-10.54371-0.21000.h5
# Epoch 2/10
# 23/23 [==============================] - 544s 24s/step - loss: 7.5269 - categorical_accuracy: 0.8250 - val_loss: 8.5609 - val_categorical_accuracy: 0.1500
#
# Epoch 00002: saving model to model_init_2022-07-13_004053\model-00002-7.52689-0.82504-8.56086-0.15000.h5
# Epoch 3/10
# 23/23 [==============================] - 546s 24s/step - loss: 3.9016 - categorical_accuracy: 0.8944 - val_loss: 8.0601 - val_categorical_accuracy: 0.2100
#
# Epoch 00003: saving model to model_init_2022-07-13_004053\model-00003-3.90161-0.89442-8.06011-0.21000.h5
# Epoch 4/10
# 23/23 [==============================] - 489s 21s/step - loss: 1.3669 - categorical_accuracy: 0.9593 - val_loss: 16.4997 - val_categorical_accuracy: 0.2800
#
# Epoch 00004: saving model to model_init_2022-07-13_004053\model-00004-1.36692-0.95928-16.49968-0.28000.h5
# Epoch 5/10
# 23/23 [==============================] - 354s 15s/step - loss: 7.0313 - categorical_accuracy: 0.8431 - val_loss: 44.4053 - val_categorical_accuracy: 0.2600
#
# Epoch 00005: saving model to model_init_2022-07-13_004053\model-00005-7.03133-0.84314-44.40532-0.26000.h5
# Epoch 6/10
# 23/23 [==============================] - 389s 17s/step - loss: 5.9601 - categorical_accuracy: 0.8854 - val_loss: 39.4095 - val_categorical_accuracy: 0.2300
#
# Epoch 00006: saving model to model_init_2022-07-13_004053\model-00006-5.96007-0.88537-39.40949-0.23000.h5
# Epoch 7/10
# 23/23 [==============================] - 367s 16s/step - loss: 2.9861 - categorical_accuracy: 0.9382 - val_loss: 68.5735 - val_categorical_accuracy: 0.2800
#
# Epoch 00007: saving model to model_init_2022-07-13_004053\model-00007-2.98607-0.93816-68.57348-0.28000.h5
# Epoch 8/10
# 23/23 [==============================] - 344s 15s/step - loss: 3.2556 - categorical_accuracy: 0.9291 - val_loss: 97.0361 - val_categorical_accuracy: 0.2900
#
# Epoch 00008: saving model to model_init_2022-07-13_004053\model-00008-3.25556-0.92911-97.03607-0.29000.h5
# Epoch 9/10
# 23/23 [==============================] - 353s 15s/step - loss: 0.9758 - categorical_accuracy: 0.9623 - val_loss: 79.7138 - val_categorical_accuracy: 0.2700
#
# Epoch 00009: saving model to model_init_2022-07-13_004053\model-00009-0.97575-0.96229-79.71375-0.27000.h5
# Epoch 10/10
# 23/23 [==============================] - 347s 15s/step - loss: 0.3156 - categorical_accuracy: 0.9819 - val_loss: 84.0788 - val_categorical_accuracy: 0.2900
#
# Epoch 00010: saving model to model_init_2022-07-13_004053\model-00010-0.31562-0.98190-84.07883-0.29000.h5

# %%
accuracy_loss_plt(model_history)
# Out:
# best_val_accuracy: 0.28999999165534973
# best_val_loss: 8.060107231140137

# %% [markdown]
# #### A very simple cnn3d model implemeted and ran for only 10 epochs just for experimenting. Hyper-parameter tuning and more layers to be added. Still in progress
